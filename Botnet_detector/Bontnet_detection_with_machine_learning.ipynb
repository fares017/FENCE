# %% [markdown]
# # Botnet detection with machine learning

# %% [markdown]
# # Converting the netflow file to a vector data

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\programdata\anaconda3\envs\fp_env\lib\site-packages (2.0.2)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\envs\fp_env\lib\site-packages (from xgboost) (1.26.0)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\envs\fp_env\lib\site-packages (from xgboost) (1.11.3)

# %%
#Importing packages
import pandas as pd
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# %%
import pandas as pd
from keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import confusion_matrix, precision_score, f1_score, accuracy_score, recall_score
from numpy import argmax
from tensorflow.keras.models import save_model, load_model

# %%
binetflow_file_path = 'capture20110810.binetflow'

# Read the binary flow file into a pandas DataFrame
df = pd.read_csv(binetflow_file_path, delimiter=',')
df.head()
# Out:
#                     StartTime          Dur Proto        SrcAddr  Sport    Dir  \
# 0  2011/08/10 09:46:53.047277  3550.182373   udp  212.50.71.179  39678    <->
# 1  2011/08/10 09:46:53.048843     0.000883   udp  84.13.246.132  28431    <->
# 2  2011/08/10 09:46:53.049895     0.000326   tcp  217.163.21.35     80    <?>
# 3  2011/08/10 09:46:53.053771     0.056966   tcp     83.3.77.74  32882    <?>
# 4  2011/08/10 09:46:53.053937  3427.768066   udp  74.89.223.204  21278    <->
#
#          DstAddr  Dport  State  sTos  dTos  TotPkts  TotBytes  SrcBytes  \
# 0  147.32.84.229  13363    CON   0.0   0.0       12       875       413
# 1  147.32.84.229  13363    CON   0.0   0.0        2       135        75
# 2  147.32.86.194   2063   FA_A   0.0   0.0        2       120        60
# 3    147.32.85.5  21857  FA_FA   0.0   0.0        3       180       120
# 4  147.32.84.229  13363    CON   0.0   0.0       42      2856      1596
#
#                              Label
# 0  flow=Background-UDP-Established
# 1  flow=Background-UDP-Established
# 2                  flow=Background
# 3                  flow=Background
# 4  flow=Background-UDP-Established

# %%
#Dropping unneccesary columns
df.drop(['StartTime'],axis=1,inplace = True)

# %%
df.State.nunique()
# Out:
# 230

# %%
df.head()
# Out:
#            Dur Proto        SrcAddr  Sport    Dir        DstAddr  Dport  \
# 0  3550.182373   udp  212.50.71.179  39678    <->  147.32.84.229  13363
# 1     0.000883   udp  84.13.246.132  28431    <->  147.32.84.229  13363
# 2     0.000326   tcp  217.163.21.35     80    <?>  147.32.86.194   2063
# 3     0.056966   tcp     83.3.77.74  32882    <?>    147.32.85.5  21857
# 4  3427.768066   udp  74.89.223.204  21278    <->  147.32.84.229  13363
#
#    State  sTos  dTos  TotPkts  TotBytes  SrcBytes  \
# 0    CON   0.0   0.0       12       875       413
# 1    CON   0.0   0.0        2       135        75
# 2   FA_A   0.0   0.0        2       120        60
# 3  FA_FA   0.0   0.0        3       180       120
# 4    CON   0.0   0.0       42      2856      1596
#
#                              Label
# 0  flow=Background-UDP-Established
# 1  flow=Background-UDP-Established
# 2                  flow=Background
# 3                  flow=Background
# 4  flow=Background-UDP-Established

# %%
#Renaming the columns using their proper names from the previous dataset
df.rename(columns = {list(df)[0]:'Duration',list(df)[1]:'Protocol',list(df)[2]:'Source_IP',list(df)[3]:'Source_Port',
                    list(df)[5]:'Destination_IP',list(df)[6]:'Destination_Port',list(df)[7]:'Flags',list(df)[8]:'Source_Type_of_Service',
                    list(df)[9]:'Dest_Type_of_Service',list(df)[10]:'Packets',list(df)[11]:'Total_Bytes',list(df)[12]:'Source_Bytes'}, inplace = True)

# %%
df.head()
# Out:
#       Duration Protocol      Source_IP Source_Port    Dir Destination_IP  \
# 0  3550.182373      udp  212.50.71.179       39678    <->  147.32.84.229
# 1     0.000883      udp  84.13.246.132       28431    <->  147.32.84.229
# 2     0.000326      tcp  217.163.21.35          80    <?>  147.32.86.194
# 3     0.056966      tcp     83.3.77.74       32882    <?>    147.32.85.5
# 4  3427.768066      udp  74.89.223.204       21278    <->  147.32.84.229
#
#   Destination_Port  Flags  Source_Type_of_Service  Dest_Type_of_Service  \
# 0            13363    CON                     0.0                   0.0
# 1            13363    CON                     0.0                   0.0
# 2             2063   FA_A                     0.0                   0.0
# 3            21857  FA_FA                     0.0                   0.0
# 4            13363    CON                     0.0                   0.0
#
#    Packets  Total_Bytes  Source_Bytes                            Label
# 0       12          875           413  flow=Background-UDP-Established
# 1        2          135            75  flow=Background-UDP-Established
# 2        2          120            60                  flow=Background
# 3        3          180           120                  flow=Background
# 4       42         2856          1596  flow=Background-UDP-Established

# %%
df.Dir.unique()
# Out:
# array(['  <->', '  <?>', '   ->', '   ?>', '  who', '  <-', '  <?'],
#       dtype=object)

# %%
direction = ['   ->','  <->','  <-']
df = df.loc[df['Dir'].isin(direction)]

# %%
df #Now 2.813Million rows - Only about 10,000 values removed from 2.824Million rows
# Out:
#             Duration Protocol        Source_IP Source_Port    Dir  \
# 0        3550.182373      udp    212.50.71.179       39678    <->
# 1           0.000883      udp    84.13.246.132       28431    <->
# 4        3427.768066      udp    74.89.223.204       21278    <->
# 6        3589.631348      udp  182.239.167.121       49649    <->
# 8        3118.470947      udp    24.117.206.20        8697    <->
# ...              ...      ...              ...         ...    ...
# 2824631     0.000393      udp     147.32.86.92       36363    <->
# 2824632     0.000935      udp     58.165.41.84       60122    <->
# 2824633     0.000000      tcp    147.32.84.171       47077     ->
# 2824634     0.002618      udp      93.79.39.15       10520    <->
# 2824635     0.001122      udp    78.56.231.126       29419    <->
#
#         Destination_IP Destination_Port Flags  Source_Type_of_Service  \
# 0        147.32.84.229            13363   CON                     0.0
# 1        147.32.84.229            13363   CON                     0.0
# 4        147.32.84.229            13363   CON                     0.0
# 6        147.32.84.229            13363   CON                     0.0
# 8        147.32.84.229            13363   CON                     0.0
# ...                ...              ...   ...                     ...
# 2824631    147.32.80.9               53   CON                     0.0
# 2824632  147.32.84.229            13363   CON                     0.0
# 2824633  78.191.168.43            13754    S_                     0.0
# 2824634  147.32.84.229            13363   CON                     0.0
# 2824635  147.32.84.229            13363   CON                     0.0
#
#          Dest_Type_of_Service  Packets  Total_Bytes  Source_Bytes  \
# 0                         0.0       12          875           413
# 1                         0.0        2          135            75
# 4                         0.0       42         2856          1596
# 6                         0.0       12         1494          1122
# 8                         0.0       13         4328           840
# ...                       ...      ...          ...           ...
# 2824631                   0.0        2          208            79
# 2824632                   0.0        2          539            75
# 2824633                   NaN        1           74            74
# 2824634                   0.0        2          520           460
# 2824635                   0.0        2          137            77
#
#                                           Label
# 0               flow=Background-UDP-Established
# 1               flow=Background-UDP-Established
# 4               flow=Background-UDP-Established
# 6               flow=Background-UDP-Established
# 8               flow=Background-UDP-Established
# ...                                         ...
# 2824631  flow=To-Background-UDP-CVUT-DNS-Server
# 2824632         flow=Background-UDP-Established
# 2824633             flow=Background-TCP-Attempt
# 2824634         flow=Background-UDP-Established
# 2824635         flow=Background-UDP-Established
#
# [2813908 rows x 14 columns]

# %%
df.replace(['   ->','  <->','  <-'],  
                            ['outgoing','two-way','incoming'],inplace=True)
# df.replace({'Dir':{'   ->': 'outgoing', '  <->': 'two-way', '  <-': 'incoming'}})

# %%
df.Dir.unique()
# Out:
# array(['two-way', 'outgoing', 'incoming'], dtype=object)

# %%
df.rename(columns = {list(df)[4]:'Direction'}, inplace = True)

# %%
df
# Out:
#             Duration Protocol        Source_IP Source_Port Direction  \
# 0        3550.182373      udp    212.50.71.179       39678   two-way
# 1           0.000883      udp    84.13.246.132       28431   two-way
# 4        3427.768066      udp    74.89.223.204       21278   two-way
# 6        3589.631348      udp  182.239.167.121       49649   two-way
# 8        3118.470947      udp    24.117.206.20        8697   two-way
# ...              ...      ...              ...         ...       ...
# 2824631     0.000393      udp     147.32.86.92       36363   two-way
# 2824632     0.000935      udp     58.165.41.84       60122   two-way
# 2824633     0.000000      tcp    147.32.84.171       47077  outgoing
# 2824634     0.002618      udp      93.79.39.15       10520   two-way
# 2824635     0.001122      udp    78.56.231.126       29419   two-way
#
#         Destination_IP Destination_Port Flags  Source_Type_of_Service  \
# 0        147.32.84.229            13363   CON                     0.0
# 1        147.32.84.229            13363   CON                     0.0
# 4        147.32.84.229            13363   CON                     0.0
# 6        147.32.84.229            13363   CON                     0.0
# 8        147.32.84.229            13363   CON                     0.0
# ...                ...              ...   ...                     ...
# 2824631    147.32.80.9               53   CON                     0.0
# 2824632  147.32.84.229            13363   CON                     0.0
# 2824633  78.191.168.43            13754    S_                     0.0
# 2824634  147.32.84.229            13363   CON                     0.0
# 2824635  147.32.84.229            13363   CON                     0.0
#
#          Dest_Type_of_Service  Packets  Total_Bytes  Source_Bytes  \
# 0                         0.0       12          875           413
# 1                         0.0        2          135            75
# 4                         0.0       42         2856          1596
# 6                         0.0       12         1494          1122
# 8                         0.0       13         4328           840
# ...                       ...      ...          ...           ...
# 2824631                   0.0        2          208            79
# 2824632                   0.0        2          539            75
# 2824633                   NaN        1           74            74
# 2824634                   0.0        2          520           460
# 2824635                   0.0        2          137            77
#
#                                           Label
# 0               flow=Background-UDP-Established
# 1               flow=Background-UDP-Established
# 4               flow=Background-UDP-Established
# 6               flow=Background-UDP-Established
# 8               flow=Background-UDP-Established
# ...                                         ...
# 2824631  flow=To-Background-UDP-CVUT-DNS-Server
# 2824632         flow=Background-UDP-Established
# 2824633             flow=Background-TCP-Attempt
# 2824634         flow=Background-UDP-Established
# 2824635         flow=Background-UDP-Established
#
# [2813908 rows x 14 columns]

# %%
df.Label.unique()
# Out:
# array(['flow=Background-UDP-Established',
#        'flow=Background-TCP-Established',
#        'flow=To-Background-UDP-CVUT-DNS-Server',
#        'flow=Background-UDP-Attempt',
#        'flow=From-Normal-V42-UDP-CVUT-DNS-Server',
#        'flow=Background-Established-cmpgw-CVUT',
#        'flow=Background-UDP-NTP-Established-1',
#        'flow=To-Background-CVUT-WebServer',
#        'flow=Background-Attempt-cmpgw-CVUT', 'flow=Background',
#        'flow=From-Background-CVUT-Proxy', 'flow=To-Background-CVUT-Proxy',
#        'flow=Background-google-analytics3', 'flow=From-Normal-V42-Jist',
#        'flow=Background-TCP-Attempt',
#        'flow=Background-google-analytics14',
#        'flow=Background-ajax.google', 'flow=Background-google-analytics6',
#        'flow=Background-google-analytics13', 'flow=Background-google-pop',
#        'flow=To-Normal-V42-UDP-NTP-server',
#        'flow=From-Normal-V42-Stribrek',
#        'flow=Background-google-analytics1',
#        'flow=Background-google-analytics16',
#        'flow=Background-google-analytics10',
#        'flow=Background-google-analytics9',
#        'flow=Background-google-analytics5',
#        'flow=Background-google-analytics12',
#        'flow=Background-google-webmail',
#        'flow=Background-google-analytics15',
#        'flow=Background-google-analytics4',
#        'flow=Background-google-analytics11',
#        'flow=From-Normal-V42-CVUT-WebServer',
#        'flow=To-Background-MatLab-Server',
#        'flow=Background-google-analytics8',
#        'flow=Background-google-analytics7',
#        'flow=Background-google-analytics2', 'flow=From-Normal-V42-Grill',
#        'flow=To-Background-Stribrek', 'flow=To-Background-Grill',
#        'flow=Background-www.fel.cvut.cz',
#        'flow=Normal-V42-HTTP-windowsupdate', 'flow=To-Background-Jist',
#        'flow=From-Botnet-V42-UDP-DNS',
#        'flow=From-Botnet-V42-TCP-HTTP-Google-Net-Established-6',
#        'flow=From-Botnet-V42-TCP-Established',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Binary-Download-1',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Binary-Download-Custom-Port-7',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Binary-Download-3',
#        'flow=From-Botnet-V42-TCP-CC6-Plain-HTTP-Encrypted-Data',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Binary-Download-Custom-Port-4',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-63',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Binary-Download-9',
#        'flow=From-Botnet-V42-TCP-WEB-Established',
#        'flow=From-Botnet-V42-TCP-Attempt',
#        'flow=From-Botnet-V42-TCP-CC54-Custom-Encryption',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-64',
#        'flow=From-Botnet-V42-TCP-CC53-HTTP-Not-Encrypted',
#        'flow=From-Botnet-V42-TCP-Attempt-SPAM',
#        'flow=From-Botnet-V42-TCP-CC1-HTTP-Not-Encrypted',
#        'flow=From-Botnet-V42-TCP-Not-Encrypted-SMTP-Private-Proxy-1',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-40',
#        'flow=From-Botnet-V42-UDP-Established',
#        'flow=From-Botnet-V42-TCP-CC16-HTTP-Not-Encrypted',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-15',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-44',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-16',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Adobe-4',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-18',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-20',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-37',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-59',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-25',
#        'flow=From-Botnet-V42-TCP-Established-SPAM',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-1',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-yieldmanager-9',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Binary-Download-Custom-Port-5',
#        'flow=From-Botnet-V42-TCP-HTTP-Not-Encrypted-Down-2',
#        'flow=From-Botnet-V42-TCP-CC55-Custom-Encryption',
#        'flow=From-Botnet-V42-TCP-WEB-Established-SSL',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-12',
#        'flow=From-Botnet-V42-TCP-Established-Custom-Encryption-3',
#        'flow=From-Botnet-V42-TCP-Established-Custom-Encryption-2',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-21',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-55',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-5',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-53',
#        'flow=From-Botnet-V42-TCP-Established-SSL-To-Microsoft-4',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-47',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-30',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-10',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-6',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-51',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-32',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-3',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-57',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-60',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-41',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-61',
#        'flow=From-Botnet-V42-ICMP',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-48',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-28',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-42',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-50',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-7',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-33',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-45',
#        'flow=From-Botnet-V42-UDP-Attempt-DNS',
#        'flow=From-Normal-V42-MatLab-Server',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-52',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-49',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-34',
#        'flow=Background-CS-Host-CVUT'], dtype=object)

# %%
df['Label'] = df['Label'].str.replace(r'flow=', '')

# %%
df['Label'] = df['Label'].str.replace(r'From-', '')

# %%
df['Label'] = df['Label'].str.replace(r'To-', '')

# %%
df['Label'] = df['Label'].str.extract(r'(\w+)')

# %%
df.Label.unique()
# Out:
# array(['Background', 'Normal', 'Botnet'], dtype=object)

# %%
df
# Out:
#             Duration Protocol        Source_IP Source_Port Direction  \
# 0        3550.182373      udp    212.50.71.179       39678   two-way
# 1           0.000883      udp    84.13.246.132       28431   two-way
# 4        3427.768066      udp    74.89.223.204       21278   two-way
# 6        3589.631348      udp  182.239.167.121       49649   two-way
# 8        3118.470947      udp    24.117.206.20        8697   two-way
# ...              ...      ...              ...         ...       ...
# 2824631     0.000393      udp     147.32.86.92       36363   two-way
# 2824632     0.000935      udp     58.165.41.84       60122   two-way
# 2824633     0.000000      tcp    147.32.84.171       47077  outgoing
# 2824634     0.002618      udp      93.79.39.15       10520   two-way
# 2824635     0.001122      udp    78.56.231.126       29419   two-way
#
#         Destination_IP Destination_Port Flags  Source_Type_of_Service  \
# 0        147.32.84.229            13363   CON                     0.0
# 1        147.32.84.229            13363   CON                     0.0
# 4        147.32.84.229            13363   CON                     0.0
# 6        147.32.84.229            13363   CON                     0.0
# 8        147.32.84.229            13363   CON                     0.0
# ...                ...              ...   ...                     ...
# 2824631    147.32.80.9               53   CON                     0.0
# 2824632  147.32.84.229            13363   CON                     0.0
# 2824633  78.191.168.43            13754    S_                     0.0
# 2824634  147.32.84.229            13363   CON                     0.0
# 2824635  147.32.84.229            13363   CON                     0.0
#
#          Dest_Type_of_Service  Packets  Total_Bytes  Source_Bytes       Label
# 0                         0.0       12          875           413  Background
# 1                         0.0        2          135            75  Background
# 4                         0.0       42         2856          1596  Background
# 6                         0.0       12         1494          1122  Background
# 8                         0.0       13         4328           840  Background
# ...                       ...      ...          ...           ...         ...
# 2824631                   0.0        2          208            79  Background
# 2824632                   0.0        2          539            75  Background
# 2824633                   NaN        1           74            74  Background
# 2824634                   0.0        2          520           460  Background
# 2824635                   0.0        2          137            77  Background
#
# [2813908 rows x 14 columns]

# %%
df.dropna(inplace=True)

# %%
df #dropping all null values removes 200k records = 2.613Million rows
# Out:
#             Duration Protocol        Source_IP Source_Port Direction  \
# 0        3550.182373      udp    212.50.71.179       39678   two-way
# 1           0.000883      udp    84.13.246.132       28431   two-way
# 4        3427.768066      udp    74.89.223.204       21278   two-way
# 6        3589.631348      udp  182.239.167.121       49649   two-way
# 8        3118.470947      udp    24.117.206.20        8697   two-way
# ...              ...      ...              ...         ...       ...
# 2824630     0.000330      udp     147.32.86.92       36363   two-way
# 2824631     0.000393      udp     147.32.86.92       36363   two-way
# 2824632     0.000935      udp     58.165.41.84       60122   two-way
# 2824634     0.002618      udp      93.79.39.15       10520   two-way
# 2824635     0.001122      udp    78.56.231.126       29419   two-way
#
#         Destination_IP Destination_Port Flags  Source_Type_of_Service  \
# 0        147.32.84.229            13363   CON                     0.0
# 1        147.32.84.229            13363   CON                     0.0
# 4        147.32.84.229            13363   CON                     0.0
# 6        147.32.84.229            13363   CON                     0.0
# 8        147.32.84.229            13363   CON                     0.0
# ...                ...              ...   ...                     ...
# 2824630    147.32.80.9               53   CON                     0.0
# 2824631    147.32.80.9               53   CON                     0.0
# 2824632  147.32.84.229            13363   CON                     0.0
# 2824634  147.32.84.229            13363   CON                     0.0
# 2824635  147.32.84.229            13363   CON                     0.0
#
#          Dest_Type_of_Service  Packets  Total_Bytes  Source_Bytes       Label
# 0                         0.0       12          875           413  Background
# 1                         0.0        2          135            75  Background
# 4                         0.0       42         2856          1596  Background
# 6                         0.0       12         1494          1122  Background
# 8                         0.0       13         4328           840  Background
# ...                       ...      ...          ...           ...         ...
# 2824630                   0.0        2          296            79  Background
# 2824631                   0.0        2          208            79  Background
# 2824632                   0.0        2          539            75  Background
# 2824634                   0.0        2          520           460  Background
# 2824635                   0.0        2          137            77  Background
#
# [2613156 rows x 14 columns]

# %%
df['Source_Type_of_Service'].unique()
# Out:
# array([0., 3., 2., 1.])

# %%
df['Dest_Type_of_Service'].unique()
# Out:
# array([0., 2., 3., 1.])

# %% [markdown]
# # Label Encoding all Categorical Variables

# %% [markdown]
# ### Direction

# %%
# Import label encoder 
from sklearn import preprocessing 
  
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'species'. 
cat_dir_data= label_encoder.fit_transform(df[['Direction']]) 
New_cat_dir = pd.DataFrame(cat_dir_data)
New_cat_dir=New_cat_dir.rename(columns={0:'Direction'})

# %%
New_cat_dir.Direction.nunique()
# Out:
# 3

# %% [markdown]
# ### Protocol

# %%
df.Protocol.unique()
# Out:
# array(['udp', 'tcp', 'rtp', 'icmp', 'rtcp', 'udt'], dtype=object)

# %%
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'species'. 
Protocol_Copy= label_encoder.fit_transform(df[['Protocol']]) 
New_cat_protocol = pd.DataFrame(Protocol_Copy)
New_cat_protocol=New_cat_protocol.rename(columns={0:'Protocol'})

# %%
New_cat_protocol.Protocol.nunique()
# Out:
# 6

# %% [markdown]
# ### Flags

# %%
df.Flags.nunique()
# Out:
# 169

# %%
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'species'. 
cat_flags_data= label_encoder.fit_transform(df[['Flags']]) 
New_cat_flags = pd.DataFrame(cat_flags_data)
New_cat_flags=New_cat_flags.rename(columns={0:'Flags'})

# %%
New_cat_flags.nunique()
# Out:
# Flags    169
# dtype: int64

# %% [markdown]
# ### Ports

# %%
imp_ports = ['22', '443', '80', '53', '389', '25', '113', '123', '554', '520', '161', '995', '67', '993', '631', '110',
 '143', '0', '445', '137', '427', '138', '524', '514', '139', '1000', '784', '12', '465', '592', '587', '88', '2', '888', '21',
 '500', '544', '81', '418', '294', '34', '98', '68', '709', '23', '8', '625', '768', '579', '135', '104', '916', '877', '310',
 '490', '1', '82', '369', '1013', '83', '832', '843', '471', '118']

# %%
len(imp_ports)
# Out:
# 64

# %%
df['ports'] = df['Destination_Port'].where(df['Destination_Port'].isin(imp_ports), 'NaN')

# %%
df.ports.value_counts()
# Out:
# ports
# NaN     1279389
# 53       989469
# 80       254554
# 443       68655
# 22        11002
# 123        2743
# 993        2316
# 110        1340
# 25         1214
# 995         999
# 113         378
# 21          322
# 161         292
# 143         113
# 587          71
# 427          66
# 465          44
# 81           34
# 631          28
# 843          24
# 389          16
# 524          15
# 139          14
# 500          11
# 23           10
# 888          10
# 82            7
# 118           4
# 1             3
# 88            2
# 12            2
# 1000          2
# 554           2
# 544           1
# 1013          1
# 916           1
# 8             1
# 592           1
# Name: count, dtype: int64

# %%
df = df[df.ports != 'NaN']

# %%
df
# Out:
#          Duration Protocol      Source_IP Source_Port Direction  \
# 11       0.187434      tcp  147.32.86.194        2065  outgoing
# 29       0.000368      udp  147.32.84.138       42315   two-way
# 30       0.000225      udp  147.32.84.138       42626   two-way
# 33       0.000227      udp  147.32.84.138       58276   two-way
# 34       0.000272      udp  147.32.84.138       58867   two-way
# ...           ...      ...            ...         ...       ...
# 2824625  0.000271      udp  147.32.84.138       52130   two-way
# 2824626  0.000207      udp  147.32.84.138       35552   two-way
# 2824627  0.000207      udp  147.32.84.138       58286   two-way
# 2824630  0.000330      udp   147.32.86.92       36363   two-way
# 2824631  0.000393      udp   147.32.86.92       36363   two-way
#
#         Destination_IP Destination_Port      Flags  Source_Type_of_Service  \
# 11       217.163.21.35               80  FSPA_FSPA                     0.0
# 29         147.32.80.9               53        CON                     0.0
# 30         147.32.80.9               53        CON                     0.0
# 33         147.32.80.9               53        CON                     0.0
# 34         147.32.80.9               53        CON                     0.0
# ...                ...              ...        ...                     ...
# 2824625    147.32.80.9               53        CON                     0.0
# 2824626    147.32.80.9               53        CON                     0.0
# 2824627    147.32.80.9               53        CON                     0.0
# 2824630    147.32.80.9               53        CON                     0.0
# 2824631    147.32.80.9               53        CON                     0.0
#
#          Dest_Type_of_Service  Packets  Total_Bytes  Source_Bytes       Label  \
# 11                        0.0       11         3872          1147  Background
# 29                        0.0        2          214            81  Background
# 30                        0.0        2          214            81  Background
# 33                        0.0        2          214            81  Background
# 34                        0.0        2          214            81  Background
# ...                       ...      ...          ...           ...         ...
# 2824625                   0.0        2          214            81  Background
# 2824626                   0.0        2          214            81  Background
# 2824627                   0.0        2          214            81  Background
# 2824630                   0.0        2          296            79  Background
# 2824631                   0.0        2          208            79  Background
#
#         ports
# 11         80
# 29         53
# 30         53
# 33         53
# 34         53
# ...       ...
# 2824625    53
# 2824626    53
# 2824627    53
# 2824630    53
# 2824631    53
#
# [1333767 rows x 15 columns]

# %% [markdown]
# # Merging everything

# %%
Interval_Variables = df[['Source_IP','Destination_IP','Duration','Packets','Total_Bytes','Source_Bytes','ports']]
Interval_Variables.head()
# Out:
#         Source_IP Destination_IP  Duration  Packets  Total_Bytes  \
# 11  147.32.86.194  217.163.21.35  0.187434       11         3872
# 29  147.32.84.138    147.32.80.9  0.000368        2          214
# 30  147.32.84.138    147.32.80.9  0.000225        2          214
# 33  147.32.84.138    147.32.80.9  0.000227        2          214
# 34  147.32.84.138    147.32.80.9  0.000272        2          214
#
#     Source_Bytes ports
# 11          1147    80
# 29            81    53
# 30            81    53
# 33            81    53
# 34            81    53

# %%
a = pd.merge(Interval_Variables, New_cat_flags, right_index=True,left_index=True)
b = pd.merge(a, New_cat_protocol, right_index=True,left_index=True)
final_X = pd.merge(b, New_cat_dir, right_index=True,left_index=True)

# %%
final_X
# Out:
#              Source_IP Destination_IP   Duration  Packets  Total_Bytes  \
# 11       147.32.86.194  217.163.21.35   0.187434       11         3872
# 29       147.32.84.138    147.32.80.9   0.000368        2          214
# 30       147.32.84.138    147.32.80.9   0.000225        2          214
# 33       147.32.84.138    147.32.80.9   0.000227        2          214
# 34       147.32.84.138    147.32.80.9   0.000272        2          214
# ...                ...            ...        ...      ...          ...
# 2613143  147.32.84.170   69.63.189.59  10.794330        7          482
# 2613144  147.32.84.170   69.63.189.59  10.794090        7          482
# 2613145  147.32.84.170  66.220.153.15  10.794067        7          482
# 2613146  147.32.84.170  66.220.153.15  10.793828        7          482
# 2613147  147.32.84.170  66.220.153.15  10.793763        7          482
#
#          Source_Bytes ports  Flags  Protocol  Direction
# 11               1147    80      4         4          2
# 29                 81    53      4         4          2
# 30                 81    53      4         4          2
# 33                 81    53      4         4          2
# 34                 81    53      4         4          2
# ...               ...   ...    ...       ...        ...
# 2613143           272    80      4         4          2
# 2613144           272    80      4         4          2
# 2613145           272    80      4         4          2
# 2613146           272    80      4         4          2
# 2613147           272    80      4         4          2
#
# [1233207 rows x 10 columns]

# %%
final_X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1233207 entries, 11 to 2613147
# Data columns (total 10 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   Source_IP       1233207 non-null  object
#  1   Destination_IP  1233207 non-null  object
#  2   Duration        1233207 non-null  float64
#  3   Packets         1233207 non-null  int64
#  4   Total_Bytes     1233207 non-null  int64
#  5   Source_Bytes    1233207 non-null  int64
#  6   ports           1233207 non-null  object
#  7   Flags           1233207 non-null  int32
#  8   Protocol        1233207 non-null  int32
#  9   Direction       1233207 non-null  int32
# dtypes: float64(1), int32(3), int64(3), object(3)
# memory usage: 89.4+ MB

# %% [markdown]
# # Defining X and y variables
# ## Target

# %%
df
# Out:
#          Duration Protocol      Source_IP Source_Port Direction  \
# 11       0.187434      tcp  147.32.86.194        2065  outgoing
# 29       0.000368      udp  147.32.84.138       42315   two-way
# 30       0.000225      udp  147.32.84.138       42626   two-way
# 33       0.000227      udp  147.32.84.138       58276   two-way
# 34       0.000272      udp  147.32.84.138       58867   two-way
# ...           ...      ...            ...         ...       ...
# 2824625  0.000271      udp  147.32.84.138       52130   two-way
# 2824626  0.000207      udp  147.32.84.138       35552   two-way
# 2824627  0.000207      udp  147.32.84.138       58286   two-way
# 2824630  0.000330      udp   147.32.86.92       36363   two-way
# 2824631  0.000393      udp   147.32.86.92       36363   two-way
#
#         Destination_IP Destination_Port      Flags  Source_Type_of_Service  \
# 11       217.163.21.35               80  FSPA_FSPA                     0.0
# 29         147.32.80.9               53        CON                     0.0
# 30         147.32.80.9               53        CON                     0.0
# 33         147.32.80.9               53        CON                     0.0
# 34         147.32.80.9               53        CON                     0.0
# ...                ...              ...        ...                     ...
# 2824625    147.32.80.9               53        CON                     0.0
# 2824626    147.32.80.9               53        CON                     0.0
# 2824627    147.32.80.9               53        CON                     0.0
# 2824630    147.32.80.9               53        CON                     0.0
# 2824631    147.32.80.9               53        CON                     0.0
#
#          Dest_Type_of_Service  Packets  Total_Bytes  Source_Bytes       Label  \
# 11                        0.0       11         3872          1147  Background
# 29                        0.0        2          214            81  Background
# 30                        0.0        2          214            81  Background
# 33                        0.0        2          214            81  Background
# 34                        0.0        2          214            81  Background
# ...                       ...      ...          ...           ...         ...
# 2824625                   0.0        2          214            81  Background
# 2824626                   0.0        2          214            81  Background
# 2824627                   0.0        2          214            81  Background
# 2824630                   0.0        2          296            79  Background
# 2824631                   0.0        2          208            79  Background
#
#         ports
# 11         80
# 29         53
# 30         53
# 33         53
# 34         53
# ...       ...
# 2824625    53
# 2824626    53
# 2824627    53
# 2824630    53
# 2824631    53
#
# [1333767 rows x 15 columns]

# %%
Target = df.iloc[:,-2:-1]

# %%
Target.rename(columns = {-2:'label'}, inplace = True) 
Target['Label'].value_counts()
# Out:
# Label
# Background    1276112
# Normal          30144
# Botnet          27511
# Name: count, dtype: int64

# %%
#Classifying labels into two categories
#botnet = Yes
#Background,Normal = No
a = ['Botnet']
Target['yes/no'] = (df['Label'].isin(a)).astype(int)

# %%
Target['yes/no'].value_counts()
# Out:
# yes/no
# 0    1306256
# 1      27511
# Name: count, dtype: int64

# %% [markdown]
# ## Downsampling

# %%
from sklearn.utils import resample

d = pd.merge(Target, final_X, right_index=True, left_index=True)

d.head()
# Out:
#          Label  yes/no      Source_IP Destination_IP  Duration  Packets  \
# 11  Background       0  147.32.86.194  217.163.21.35  0.187434       11
# 29  Background       0  147.32.84.138    147.32.80.9  0.000368        2
# 30  Background       0  147.32.84.138    147.32.80.9  0.000225        2
# 33  Background       0  147.32.84.138    147.32.80.9  0.000227        2
# 34  Background       0  147.32.84.138    147.32.80.9  0.000272        2
#
#     Total_Bytes  Source_Bytes ports  Flags  Protocol  Direction
# 11         3872          1147    80      4         4          2
# 29          214            81    53      4         4          2
# 30          214            81    53      4         4          2
# 33          214            81    53      4         4          2
# 34          214            81    53      4         4          2

# %%
d['yes/no'].value_counts()
# Out:
# yes/no
# 0    1210617
# 1      22590
# Name: count, dtype: int64

# %%
majo = d.loc[d['yes/no']== 0]
mino = d.loc[d['yes/no']== 1]

# %%
# downsample majority class
maj_dsampled = resample(majo, 
                        replace=False,     # sample with replacement
                        n_samples=20515,   # to match minority class
                        random_state=1)    # reproducible results

# %%
dsampled = pd.concat([mino, maj_dsampled])
dsampled['yes/no'].value_counts()
# Out:
# yes/no
# 1    22590
# 0    20515
# Name: count, dtype: int64

# %% [markdown]
# ## X and Y variables

# %%
y=dsampled[['yes/no']]
X=dsampled.drop(['yes/no','Label','Source_IP','Destination_IP'],axis=1)


X
# Out:
#           Duration  Packets  Total_Bytes  Source_Bytes ports  Flags  Protocol  \
# 675537    0.000278        2          203            64    53      4         4
# 675872    0.020525        2          590            87    53      4         4
# 675877    0.045125        7          882           629    80      4         4
# 689920    0.336250        2          215            71    53      4         4
# 691663    0.459301        2          212            77    53      4         4
# ...            ...      ...          ...           ...   ...    ...       ...
# 856611    0.000129        2          214            81    53      4         4
# 2564490   0.000272        2          214            81    53      4         4
# 561572    0.000249        2          208            79    53      4         4
# 1405041  45.757549      174       136019         18555    80      4         4
# 1967581   0.000316        2          238            87    53      4         4
#
#          Direction
# 675537           2
# 675872           2
# 675877           2
# 689920           2
# 691663           2
# ...            ...
# 856611           2
# 2564490          2
# 561572           2
# 1405041          2
# 1967581          2
#
# [43105 rows x 8 columns]

# %%
y
# Out:
#          yes/no
# 675537        1
# 675872        1
# 675877        1
# 689920        1
# 691663        1
# ...         ...
# 856611        0
# 2564490       0
# 561572        0
# 1405041       0
# 1967581       0
#
# [43105 rows x 1 columns]

# %% [markdown]
# We have 41,030 records now.

# %% [markdown]
# # Applying machine learning algorithms

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3,random_state=42)
scaler_minmax = MinMaxScaler()
scaler_minmax.fit(X_train)
scaler_minmax.fit(X_test)

X_train = scaler_minmax.transform(X_train)
X_test = scaler_minmax.transform(X_test)

# %% [markdown]
# ## Decision Tree

# %%
#Decision Tree
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier(criterion='gini')
dtree.fit(X_train,y_train)
dtree.score(X_test, y_test)
# Out:
# 0.9273894215898546

# %% [markdown]
# ## Bagging Classifier

# %%
from sklearn.metrics import confusion_matrix as cm
from sklearn.ensemble import BaggingClassifier
clf = BaggingClassifier(n_estimators=10).fit(X_train, y_train)

clf.score(X_test, y_test)
# Out:
# 0.9378286421280544

# %% [markdown]
# ## XGBoost

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, f1_score
from sklearn.preprocessing import LabelEncoder

# Create a label encoder
label_encoder = LabelEncoder()

# Fit and transform the training labels
y_train_encoded = label_encoder.fit_transform(y_train)

# Transform the test labels
y_test_encoded = label_encoder.transform(y_test)

# Fitting the model. 
model = XGBClassifier()
model.fit(X_train, y_train_encoded)

# Making predictions for the test data. 
y_pred_encoded = model.predict(X_test)
predictions = y_pred_encoded

# Inverse transform the predictions to get original labels for evaluation
predictions_original = label_encoder.inverse_transform(predictions)

# Evaluating predictions for the test data. 
accuracy = accuracy_score(y_test, predictions_original)
f1 = f1_score(y_test, predictions_original, average='binary')  # Use 'micro', 'macro', or 'weighted' for multiclass

print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.9541
# F1 Score: 0.9566

# %%
# !pip install tabulate
from tabulate import tabulate

results = [
    ["Accuracy", f"{accuracy:.4f}"],
    ["F1 Score", f"{f1:.4f}"],
]

print(tabulate(results, headers=["Metric", "Score"]))
# Out:
# Collecting tabulate
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Installing collected packages: tabulate
# Successfully installed tabulate-0.9.0
# Metric      Score
# --------  -------
# Accuracy   0.9541
# F1 Score   0.9566

# %% [markdown]
# # Neural network

# %% [markdown]
# ## NN architecture 1

# %%
# Define the model
model = Sequential()
model.add(Dense(12, input_dim=X.shape[1], activation='sigmoid'))
model.add(Dense(1, activation='sigmoid'))

# %%
# Compile the model
model.compile(loss='binary_crossentropy', optimizer=Adam(lr=0.0001), metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=20, batch_size=64)
# Out:
# Epoch 1/20
# 472/472 [==============================] - 2s 1ms/step - loss: 0.8021 - accuracy: 0.5240
# Epoch 2/20
# 472/472 [==============================] - 1s 1ms/step - loss: 0.7311 - accuracy: 0.5240
# Epoch 3/20
# 472/472 [==============================] - 1s 1ms/step - loss: 0.7015 - accuracy: 0.5241
# Epoch 4/20
# 472/472 [==============================] - 1s 1ms/step - loss: 0.6924 - accuracy: 0.5260
# Epoch 5/20
# 472/472 [==============================] - 1s 1ms/step - loss: 0.6903 - accuracy: 0.5284
# Epoch 6/20
# 472/472 [==============================] - 1s 2ms/step - loss: 0.6899 - accuracy: 0.5354
# Epoch 7/20
# 472/472 [==============================] - 1s 1ms/step - loss: 0.6896 - accuracy: 0.5484
# Epoch 8/20
# 472/472 [==============================] - 1s 1ms/step - loss: 0.6894 - accuracy: 0.5486
# Epoch 9/20
# 472/472 [==============================] - 1s 1ms/step - loss: 0.6892 - accuracy: 0.5482
# Epoch 10/20
# 472/472 [==============================] - 1s 2ms/step - loss: 0.6890 - accuracy: 0.5493
# Epoch 11/20
# 472/472 [==============================] - 1s 1ms/step - loss: 0.6887 - accuracy: 0.5499
# Epoch 12/20
# 472/472 [==============================] - 1s 1ms/step - loss: 0.6885 - accuracy: 0.5505
# Epoch 13/20
# 472/472 [==============================] - 1s 1ms/step - loss: 0.6883 - accuracy: 0.5498
# Epoch 14/20
# 472/472 [==============================] - 1s 1ms/step - loss: 0.6880 - accuracy: 0.5504
# Epoch 15/20
# 472/472 [==============================] - 1s 2ms/step - loss: 0.6878 - accuracy: 0.5502
# Epoch 16/20
# 472/472 [==============================] - 1s 2ms/step - loss: 0.6876 - accuracy: 0.5501
# Epoch 17/20
# 472/472 [==============================] - 1s 1ms/step - loss: 0.6874 - accuracy: 0.5503
# Epoch 18/20
# 472/472 [==============================] - 1s 2ms/step - loss: 0.6871 - accuracy: 0.5505
# Epoch 19/20
# 472/472 [==============================] - 1s 2ms/step - loss: 0.6869 - accuracy: 0.5504
# Epoch 20/20
# 472/472 [==============================] - 1s 2ms/step - loss: 0.6867 - accuracy: 0.5506

# %%
# Predict the test set results
y_pred = model.predict(X_test)
y_pred = [1 if p >= 0.5 else 0 for p in y_pred]  # Threshold can be adjusted
# Out:
# 405/405 [==============================] - 1s 1ms/step

# %%
# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
print(f'Confusion Matrix:\n {cm}')

# Precision
precision = precision_score(y_test, y_pred)
print(f'Precision: {precision}')

# F1 Score
f1 = f1_score(y_test, y_pred)
print(f'F1 Score: {f1}')

# Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Confusion Matrix:
#  [[ 620 5533]
#  [ 288 6491]]
# Precision: 0.539836992681304
# F1 Score: 0.6904217412115088
# Accuracy: 0.5498762759047324

# %% [markdown]
# ## NN architecture 2

# %%
# Define the model
model = Sequential()
model.add(Dense(64, input_dim=X.shape[1], activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# %%
# Compile the model with an appropriate learning rate
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model with your data
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 943/943 [==============================] - 5s 3ms/step - loss: 0.7927 - accuracy: 0.5320 - val_loss: 0.6943 - val_accuracy: 0.4919
# Epoch 2/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6876 - accuracy: 0.5676 - val_loss: 0.6697 - val_accuracy: 0.6069
# Epoch 3/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6734 - accuracy: 0.5857 - val_loss: 0.6703 - val_accuracy: 0.5905
# Epoch 4/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6712 - accuracy: 0.5879 - val_loss: 0.6769 - val_accuracy: 0.4895
# Epoch 5/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6716 - accuracy: 0.5885 - val_loss: 0.6660 - val_accuracy: 0.6079
# Epoch 6/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6694 - accuracy: 0.5914 - val_loss: 0.6681 - val_accuracy: 0.6090
# Epoch 7/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6694 - accuracy: 0.5937 - val_loss: 0.6839 - val_accuracy: 0.4940
# Epoch 8/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6676 - accuracy: 0.5977 - val_loss: 0.6630 - val_accuracy: 0.6088
# Epoch 9/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6664 - accuracy: 0.5998 - val_loss: 0.6826 - val_accuracy: 0.4925
# Epoch 10/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6654 - accuracy: 0.6006 - val_loss: 0.6590 - val_accuracy: 0.6110
# Epoch 11/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6668 - accuracy: 0.5979 - val_loss: 0.6651 - val_accuracy: 0.6113
# Epoch 12/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6650 - accuracy: 0.5958 - val_loss: 0.6635 - val_accuracy: 0.6121
# Epoch 13/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6644 - accuracy: 0.6035 - val_loss: 0.6697 - val_accuracy: 0.6031
# Epoch 14/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6639 - accuracy: 0.6046 - val_loss: 0.6590 - val_accuracy: 0.6105
# Epoch 15/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6621 - accuracy: 0.6057 - val_loss: 0.6578 - val_accuracy: 0.6107
# Epoch 16/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6622 - accuracy: 0.6045 - val_loss: 0.6549 - val_accuracy: 0.6105
# Epoch 17/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6626 - accuracy: 0.6053 - val_loss: 0.6562 - val_accuracy: 0.6106
# Epoch 18/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6614 - accuracy: 0.6078 - val_loss: 0.6600 - val_accuracy: 0.6105
# Epoch 19/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6614 - accuracy: 0.6059 - val_loss: 0.6601 - val_accuracy: 0.6107
# Epoch 20/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6613 - accuracy: 0.6065 - val_loss: 0.6591 - val_accuracy: 0.6107
# Epoch 21/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6605 - accuracy: 0.6071 - val_loss: 0.6547 - val_accuracy: 0.6095
# Epoch 22/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6607 - accuracy: 0.6051 - val_loss: 0.6532 - val_accuracy: 0.6110
# Epoch 23/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6594 - accuracy: 0.6068 - val_loss: 0.6583 - val_accuracy: 0.6107
# Epoch 24/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6606 - accuracy: 0.6077 - val_loss: 0.6570 - val_accuracy: 0.6109
# Epoch 25/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6613 - accuracy: 0.6045 - val_loss: 0.6585 - val_accuracy: 0.6151
# Epoch 26/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6606 - accuracy: 0.6041 - val_loss: 0.6584 - val_accuracy: 0.6108
# Epoch 27/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6599 - accuracy: 0.6052 - val_loss: 0.6587 - val_accuracy: 0.6109
# Epoch 28/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6588 - accuracy: 0.6065 - val_loss: 0.6598 - val_accuracy: 0.6149
# Epoch 29/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6588 - accuracy: 0.6055 - val_loss: 0.6556 - val_accuracy: 0.6144
# Epoch 30/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6591 - accuracy: 0.6054 - val_loss: 0.6568 - val_accuracy: 0.6108
# Epoch 31/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6570 - accuracy: 0.6084 - val_loss: 0.6758 - val_accuracy: 0.5833
# Epoch 32/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6582 - accuracy: 0.6072 - val_loss: 0.6583 - val_accuracy: 0.6146
# Epoch 33/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6584 - accuracy: 0.6075 - val_loss: 0.6590 - val_accuracy: 0.6151
# Epoch 34/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6569 - accuracy: 0.6096 - val_loss: 0.6558 - val_accuracy: 0.6150
# Epoch 35/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6585 - accuracy: 0.6075 - val_loss: 0.6558 - val_accuracy: 0.6161
# Epoch 36/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6576 - accuracy: 0.6064 - val_loss: 0.6543 - val_accuracy: 0.6145
# Epoch 37/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6563 - accuracy: 0.6088 - val_loss: 0.6585 - val_accuracy: 0.6152
# Epoch 38/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6583 - accuracy: 0.6089 - val_loss: 0.6594 - val_accuracy: 0.6133
# Epoch 39/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6569 - accuracy: 0.6076 - val_loss: 0.6602 - val_accuracy: 0.6145
# Epoch 40/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6575 - accuracy: 0.6083 - val_loss: 0.6582 - val_accuracy: 0.6145
# Epoch 41/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6573 - accuracy: 0.6083 - val_loss: 0.6526 - val_accuracy: 0.6146
# Epoch 42/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6591 - accuracy: 0.6058 - val_loss: 0.6584 - val_accuracy: 0.6118
# Epoch 43/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6572 - accuracy: 0.6071 - val_loss: 0.6576 - val_accuracy: 0.6111
# Epoch 44/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6572 - accuracy: 0.6063 - val_loss: 0.6588 - val_accuracy: 0.6124
# Epoch 45/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6571 - accuracy: 0.6061 - val_loss: 0.6570 - val_accuracy: 0.6144
# Epoch 46/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6568 - accuracy: 0.6083 - val_loss: 0.6583 - val_accuracy: 0.6108
# Epoch 47/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6572 - accuracy: 0.6091 - val_loss: 0.6579 - val_accuracy: 0.6149
# Epoch 48/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6568 - accuracy: 0.6083 - val_loss: 0.6562 - val_accuracy: 0.6109
# Epoch 49/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6576 - accuracy: 0.6078 - val_loss: 0.6594 - val_accuracy: 0.6108
# Epoch 50/50
# 943/943 [==============================] - 3s 3ms/step - loss: 0.6562 - accuracy: 0.6105 - val_loss: 0.6594 - val_accuracy: 0.6107

# %%
# Save the trained model to an HDF5 file
save_model(model, 'raw_data_model.h5')

# %%
# Predict the test set results
y_pred = model.predict(X_test)
y_pred = [1 if p >= 0.5 else 0 for p in y_pred]  # Threshold can be adjusted

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
print(f'Confusion Matrix:\n {cm}')

# Precision
precision = precision_score(y_test, y_pred)
print(f'Precision: {precision}')

# F1 Score
f1 = f1_score(y_test, y_pred)
print(f'F1 Score: {f1}')

# Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# 405/405 [==============================] - 1s 1ms/step
# Confusion Matrix:
#  [[1534 4619]
#  [ 415 6364]]
# Precision: 0.5794409542019484
# F1 Score: 0.716585970048418
# Accuracy: 0.6107330652644603

# %%
d.rename(columns={'yes/no': 'lablel'}, inplace=True)

# %%
d.drop(columns=['Label'], inplace=True)

# %%
d
# Out:
#          lablel      Source_IP Destination_IP   Duration  Packets  \
# 11            0  147.32.86.194  217.163.21.35   0.187434       11
# 29            0  147.32.84.138    147.32.80.9   0.000368        2
# 30            0  147.32.84.138    147.32.80.9   0.000225        2
# 33            0  147.32.84.138    147.32.80.9   0.000227        2
# 34            0  147.32.84.138    147.32.80.9   0.000272        2
# ...         ...            ...            ...        ...      ...
# 2613143       0  147.32.84.170   69.63.189.59  10.794330        7
# 2613144       0  147.32.84.170   69.63.189.59  10.794090        7
# 2613145       0  147.32.84.170  66.220.153.15  10.794067        7
# 2613146       0  147.32.84.170  66.220.153.15  10.793828        7
# 2613147       0  147.32.84.170  66.220.153.15  10.793763        7
#
#          Total_Bytes  Source_Bytes ports  Flags  Protocol  Direction
# 11              3872          1147    80      4         4          2
# 29               214            81    53      4         4          2
# 30               214            81    53      4         4          2
# 33               214            81    53      4         4          2
# 34               214            81    53      4         4          2
# ...              ...           ...   ...    ...       ...        ...
# 2613143          482           272    80      4         4          2
# 2613144          482           272    80      4         4          2
# 2613145          482           272    80      4         4          2
# 2613146          482           272    80      4         4          2
# 2613147          482           272    80      4         4          2
#
# [1233207 rows x 11 columns]

# %%
# Save the DataFrame to a CSV file
df.to_csv('raw data.csv', index=False)
